# %% [markdown]
# ## Configuration

# %%
from connect_db import *

# %% [markdown]
# ## Connection to DB

# %%
conn = connect_to_db(db_name='house_plants')

# %%
pd.read_sql('SELECT * FROM plants', conn)
# Out:
#    Plant ID  Active  Iteration                               Common Name  \
# 0     P0001       1          1                    Moonlight Philodendron
# 1     P0002       1          1             Prince of Orange Philodendron
# 2     P0003       1          1                      Golden Lemon Cypress
# 3     P0004       1          1               Weeping Fig Variegated Bush
# 4     P0005       1          1                       Creeping Inch Plant
# 5     P0006       1          1                       Rubber Plant Tineke
# 6     P0007       1          1                       Rubber Plant Tineke
# 7     P0008       1          1    Rubber Plant Yellow Gem / Council Tree
# 8     P0009       1          1                          Astrid Peperomia
# 9     P0010       1          1                    Peperomia Ruby Cascade
# 10    P0011       1          1                             Green Cypress
# 11    P0012       1          1                         Peperomia Rubella
# ...
