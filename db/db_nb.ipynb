# %% [markdown]
# ## Configuration

# %%
from connect_db import *

# %% [markdown]
# ## Connection to DB

# %%
conn = connect_to_db(db_name='house_plants')

# %%
pd.read_sql('SELECT * FROM plants', conn)
# Out:
#     index Plant ID  Active  Iteration  \
# 0       0    P0001       1          1
# 1       1    P0002       1          1
# 2       2    P0003       1          1
# 3       3    P0004       1          1
# 4       4    P0005       1          1
# 5       5    P0006       1          1
# 6       6    P0007       1          1
# 7       7    P0008       1          1
# 8       8    P0009       1          1
# 9       9    P0010       1          1
# 10     10    P0011       1          1
# 11     11    P0012       1          1
# 12     12    P0013       1          1
# 13     13    P0014       1          1
# 14     14    P0015       1          1
# 15     15    P0016       1          1
# 16     16    P0017       1          1
# 17     17    P0018       1          1
# 18     18    P0019       1          1
# 19     19    P0020       1          1
# 20     20    P0021       1          1
# 21     21    P0022       1          3
# 22     22    P0023       1          1
# ...
