# %%
from shamrock import Shamrock
api = Shamrock('mytoken')
species = api.species()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\ramos\OneDrive\Documents\Plants\PlantWebApp\venv\lib\site-packages\urllib3\connection.py:158, in HTTPConnection._new_conn(self)
#     157 try:
# --> 158     conn = connection.create_connection(
#     159         (self._dns_host, self.port), self.timeout, **extra_kw)
#     161 except SocketTimeout:
#
# File c:\Users\ramos\OneDrive\Documents\Plants\PlantWebApp\venv\lib\site-packages\urllib3\util\connection.py:80, in create_connection(address, timeout, source_address, socket_options)
#      79 if err is not None:
# ---> 80     raise err
#      82 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\ramos\OneDrive\Documents\Plants\PlantWebApp\venv\lib\site-packages\urllib3\util\connection.py:70, in create_connection(address, timeout, source_address, socket_options)
# ...
